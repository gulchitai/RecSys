# %% [markdown]
# __Задание 1.__ В чем принципиальные отличия item-item рекомендаций от ALS?
# * Разные формулы для подсчета весов матрицы интеракций. В основе ItemItem лежит Knn, ALS - это параметрическая модель, на основе гадиентного спуска.
# * У ALS скорость предсказаний больше.

# %% [markdown]
# __Задание 2.__ Приведите 3 примера весов user-item матрицы для задачи рекоммендаций товаров
# * размер скидки на конкретный товар конкретному клиенту
# * количество оформленных заказов конкретного товара клиентом за год
# * на какую сумму клиент купил конкретного товара

# %% [markdown]
# __Задание 3.__ Какие ограничения есть у ALS? (Тип информации, линейность/нелинейность факторов и т д)
# * На вход принимает только позитивные взаимодействия
# * Прогнозирует не вероятность, а некоторые числа
# * В ALS нельзя добавить внешние фичи
# * ALS не учитывает сезонность / зависимость во времени

# %% [markdown]
# ### ДОПОЛНЕНО (вопросы к первому вебинару):

# %% [markdown]
# __Задание 4.__ Сравните метрики hit_rate@k, precision@k. Какую матрику использовать предпочтительно и почему. Привидите пример 2-3 задач (опишите, что является клиентом, что товаром), в которой более уместно использовать метрику hit_rate?

# %% [markdown]
# * __Hit rate__ - был ли хотя бы 1 релевантный товар среди рекомендованных
# * __Precision@k__ - доля релевантных товаров среди k рекомендованных = Какой % рекомендованных товаров юзер купил

# %% [markdown]
# Предпочтительнее использовать метрику Precision@k, но Hit rate иногда применяется, когда продаются достаточно дрогие товары (например, бытовая техника)

# %% [markdown]
# ##### Примеры
# * Задача поиска товаров аналогичных товару1. Клиент Товар1, остальные товары - товары.
# * Рекомендация музыки на Youtube. Клиент - пользователь, товар - музыкальный трек.

# %% [markdown]
# __Задание 5.__ В метрике NDCG@k мы используем логарифм в знаменатиле. Как Вы думаете, почему именно логарифм? Какую функцию можно использовать вместо логарифма?
# Привидите пример метрик/подходов к предобработке данных/функций ошибок в ML, где также в знаменателе присутсвует логарифм.

# %% [markdown]
# Используем логарифм в знаменателе потому, что мы строги к тому, чтобы у нас в топе оказались более релевантные ответы. Вместо логарифма можно выбрать любую медленно возрастающую функцию, напрмер корень из x. У 𝐷𝐶𝐺 в знаменателе есть логарифм :)
